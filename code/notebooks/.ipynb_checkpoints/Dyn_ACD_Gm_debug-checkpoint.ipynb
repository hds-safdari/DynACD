# %% [markdown]
# ## Debug notebook for the Dynamical Anomaly generative model

# %%
# import sys
# sys.path.append('../')
# sys.path.append('../Dyn_ACD') 
import yaml
import tools_temp as tlm

import Dyn_ACD_gm
import numpy as np
import pandas as pd


import matplotlib.pyplot as plt
import networkx as nx
import importlib
import sktensor as skt
from sklearn import metrics
# %matplotlib notebook
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 5
#       1 # import sys
#       2 # sys.path.append('../')
#       3 # sys.path.append('../Dyn_ACD')
#       4 import yaml
# ----> 5 import tools_temp as tlm
#       7 import Dyn_ACD_gm
#       8 import numpy as np
#
# ModuleNotFoundError: No module named 'tools_temp'

# %%
import Dyn_ACD as Dyn_ACD

# %%
with open('../setting_syn_data.yaml') as f:
    conf = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# # conf

# %%
# !mkdir ../data/input/synthetic

# %%
conf['N'] = 100
conf['K'] = 2
conf['T'] = 5
conf['avg_degree'] = 5.
conf['verbose'] = 2
# conf['folder'] = '../data/debug/'
# conf['over'] = 0.
# conf['L1'] = True 
conf['beta'] = 0.2
conf['pi'] = 0.2 
conf['ell'] = 0.2 
conf['folder'] = '../../data/input/synthetic/100_5/'
conf['flag_anomalies'] = True

# %% [markdown]
# ### Run for many seeds and eta

# %%
importlib.reload(Dyn_ACD_gm_zstatic)
importlib.reload(tools)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 importlib.reload(Dyn_ACD_gm_zstatic)
#       2 importlib.reload(tools)
#
# NameError: name 'Dyn_ACD_gm_zstatic' is not defined

# %%
conf.pop('flag_anomalies')
# Out:
# True

# %%
from scipy.sparse import random
import scipy.sparse as sparse
N=10
z = random(N,N, density=0.1, data_rvs=np.ones)
type(z)
# Out:
# scipy.sparse._coo.coo_matrix

# %%
isinstance(z,sparse.coo_matrix)
# Out:
# True

# %%
type(z)
# Out:
# scipy.sparse._coo.coo_matrix

# %%
# %%time
# conf['flag_anomalies'] = True
rseed = 0
model = {}
for rseed in range(1):
    print('-'*66)
    print('rseed:', rseed) 
    conf['prng'] = rseed 
    for rho_anomaly in [0.2]: 
        conf['rho_anomaly'] = rho_anomaly
        print('seed, rho_anomaly:', rseed, rho_anomaly)
        print('-'*30)   
        gen = Dyn_ACD.Dyn_ACD_gm_zstatic.SyntNetDynAnomaly(**conf)
        model[rseed] = gen.anomaly_network_PB()

    rseed += 1
    print('\n')
# Out:
# ------------------------------------------------------------------
# rseed: 0
# seed, rho_anomaly: 0 0.2
# ------------------------------
# Filename = 100_2_5.0_5_0.2_2_2_0.2
# [0 1 2 3]
# self.N : 100
# len(A):6
# Adjacency matrix saved in:
# ../data/input/synthetic/100_5/syn_100_2_5.0_5_0.2_2_2_0.2_0.csv.
# Removed 0 nodes, because not part of the largest connected component
# ------------------------------
# t = 0
# Number of nodes: 100
# Number of edges: 369
# Average degree (2E/N): 7.38
# Reciprocity at t: 0.07588075880758807
# ------------------------------
# ------------------------------
# t = 1
# Number of nodes: 100
# Number of edges: 371
# Average degree (2E/N): 7.42
# Reciprocity at t: 0.07547169811320754
# ------------------------------
# ------------------------------
# t = 2
# Number of nodes: 100
# Number of edges: 371
# Average degree (2E/N): 7.42
# Reciprocity at t: 0.0646900269541779
# ------------------------------
# ------------------------------
# t = 3
# ...

# %%
gen._plot_A(gen.z)

# %%
model[0]
# Out:
# {'G': [<networkx.classes.digraph.DiGraph at 0x320a1fdd0>,
# ...
#  'A': [<Compressed Sparse Row sparse array of dtype 'int64'
#   	with 369 stored elements and shape (100, 100)>,
#   <Compressed Sparse Row sparse array of dtype 'int64'
#   	with 371 stored elements and shape (100, 100)>,
#   <Compressed Sparse Row sparse array of dtype 'int64'
#   	with 371 stored elements and shape (100, 100)>,
#   <Compressed Sparse Row sparse array of dtype 'int64'
#   	with 358 stored elements and shape (100, 100)>,
#   <Compressed Sparse Row sparse array of dtype 'int64'
#   	with 355 stored elements and shape (100, 100)>,
#   <Compressed Sparse Row sparse array of dtype 'int64'
#   	with 343 stored elements and shape (100, 100)>],
#  'rec': [0.0759, 0.0755, 0.0647, 0.0559, 0.0563, 0.0816]}

# %%
# %%time
# conf['flag_anomalies'] = True
# rseed = 0
# for rseed in range(10):
#     print('-'*66)
#     print('rseed:', rseed) 
#     conf['prng'] = rseed
#     for rho_anomaly in np.linspace(0.1,0.9,9): 
#         conf['rho_anomaly'] = rho_anomaly
#         print('seed, rho_anomaly:', rseed, rho_anomaly)
#         print('-'*30)   
#         gen = Dyn_ACD.Dyn_ACD_gm.SyntNetDynAnomaly(**conf)
#         gen.anomaly_network_PB()

#     rseed += 1
#     print('\n')

# %%
df = pd.read_csv('../data/input/synthetic/100_10/syn_100_2_10.0_20_0.2_2_2_0.7_0.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df = pd.read_csv('../data/input/synthetic/100_10/syn_100_2_10.0_20_0.2_2_2_0.7_0.csv')
#
# File ~/miniconda3/envs/myenv1/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
